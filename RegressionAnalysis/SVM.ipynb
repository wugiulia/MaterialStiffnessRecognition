# %%
import pandas as pd 
import numpy as np 
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn import svm
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import f1_score 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error
import math
from sklearn.preprocessing import scale

# %%
data = pd.read_csv("PL_PL_avg.csv")

# %%
#Defining algorithm and standardization method
regressor = svm.SVR(kernel='linear')
scaler = StandardScaler()

# %%
#hyperparameter tuning
param_grid = {'C': [0.1, 1, 10],
              'epsilon': [0.1, 0.5]}
    
grid_search = GridSearchCV(regressor, param_grid, cv=5, scoring='neg_mean_squared_error')

# %%
#testing MATERIAL A - coefficent1
X_train = data.iloc[2:,3:].values
Y_train = data.iloc[2:,1:2].values
X_test = data.iloc[:2,3:].values
Y_test = data.iloc[:2,1:2].values

#scaling the data
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

Y_train=Y_train.ravel()
Y_test=Y_test.ravel()

#training the algorithm
grid_search.fit(X_train, Y_train) 

#hyperturning
best_model = grid_search.best_estimator_ 

#Predicting test set
Y_pred = best_model.predict(X_test)
    
print("Best hyperparameters:", grid_search.best_params_)

print(data.iloc[1,0])
print("\033[1mActual is:\033[0m", Y_test)
print ("\033[1mPredicted is:\033[0m", Y_pred)

def rmse(y_true, y_pred):
    # calculate mean squared error for each output
    mse = mean_squared_error(y_true, y_pred, multioutput='raw_values')
    # calculate RMSE for each output
    rmse = np.sqrt(mse)
    return rmse

RMSE=rmse(Y_test, Y_pred)

print(RMSE)
# Out:
# Best hyperparameters: {'C': 0.1, 'epsilon': 0.1}
# DS10
# Actual is: [-0.256147 -0.256147]
# Predicted is: [-0.28605961 -0.28872143]
# [0.03127185]

# %%
#testing MATERIAL A - coefficent2

X_train = data.iloc[2:,3:].values
Y_train = data.iloc[2:,2:3].values
X_test = data.iloc[:2,3:].values
Y_test = data.iloc[:2,2:3].values

#scaling the data
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

Y_train=Y_train.ravel()
Y_test=Y_test.ravel()

#training the algorithm
grid_search.fit(X_train, Y_train) 

#hyperturning
best_model = grid_search.best_estimator_ 

#Predicting test set
Y_pred = best_model.predict(X_test)
    
print("Best hyperparameters:", grid_search.best_params_)

print(data.iloc[1,0])
print("\033[1mActual is:\033[0m", Y_test)
print ("\033[1mPredicted is:\033[0m", Y_pred)

def rmse(y_true, y_pred):
    # calculate mean squared error for each output
    mse = mean_squared_error(y_true, y_pred, multioutput='raw_values')
    # calculate RMSE for each output
    rmse = np.sqrt(mse)
    return rmse

RMSE=rmse(Y_test, Y_pred)
print(RMSE)

# %%
#testing MATERIAL B - coefficient1
X_train = data.iloc[list(range(0,2))+ list(range(4, len(data)))].iloc[:,3:].values
Y_train = data.iloc[list(range(0,2)) +list(range(4, len(data)))].iloc[:,1:2].values
X_test = data.iloc[2:4,3:].values
Y_test = data.iloc[2:4,1:2].values

#scaling the data
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

Y_train=Y_train.ravel()
Y_test=Y_test.ravel()

#training the algorithm
grid_search.fit(X_train, Y_train) 

#hyperturning
best_model = grid_search.best_estimator_ 

#Predicting test set
Y_pred = best_model.predict(X_test)
    
print("Best hyperparameters:", grid_search.best_params_)

print(data.iloc[3,0])
print("\033[1mActual is:\033[0m", Y_test)
print ("\033[1mPredicted is:\033[0m", Y_pred)

def rmse(y_true, y_pred):
    # calculate mean squared error for each output
    mse = mean_squared_error(y_true, y_pred, multioutput='raw_values')
    # calculate RMSE for each output
    rmse = np.sqrt(mse)
    return rmse

RMSE=rmse(Y_test, Y_pred)

print(RMSE)
# Out:
# Best hyperparameters: {'C': 10, 'epsilon': 0.1}
# PD1
# Actual is: [2.833953 2.833953]
# Predicted is: [2.87427323 2.28248745]
# [0.39098592]

# %%
#testing MATERIAL B - coefficient2
X_train = data.iloc[list(range(0,2))+ list(range(4, len(data)))].iloc[:,3:].values
Y_train = data.iloc[list(range(0,2)) +list(range(4, len(data)))].iloc[:,2:3].values
X_test = data.iloc[2:4,3:].values
Y_test = data.iloc[2:4,2:3].values

#scaling the data
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

Y_train=Y_train.ravel()
Y_test=Y_test.ravel()

#training the algorithm
grid_search.fit(X_train, Y_train) 

#hyperturning
best_model = grid_search.best_estimator_ 

#Predicting test set
Y_pred = best_model.predict(X_test)
    
print("Best hyperparameters:", grid_search.best_params_)

print(data.iloc[3,0])
print("\033[1mActual is:\033[0m", Y_test)
print ("\033[1mPredicted is:\033[0m", Y_pred)

def rmse(y_true, y_pred):
    # calculate mean squared error for each output
    mse = mean_squared_error(y_true, y_pred, multioutput='raw_values')
    # calculate RMSE for each output
    rmse = np.sqrt(mse)
    return rmse

RMSE=rmse(Y_test, Y_pred)

print(RMSE)
# Out:
# Best hyperparameters: {'C': 1, 'epsilon': 0.1}
# PD1
# Actual is: [1.697086 1.697086]
# Predicted is: [1.84953792 1.62715325]
# [0.11860054]

# %%
#testing MATERIAL C - coefficient1
X_train = data.iloc[list(range(0,4))+ list(range(6, len(data)))].iloc[:,3:].values
Y_train = data.iloc[list(range(0,4)) +list(range(6, len(data)))].iloc[:,1:2].values
X_test = data.iloc[4:6,3:].values
Y_test = data.iloc[4:6,1:2].values

#scaling the data
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

Y_train=Y_train.ravel()
Y_test=Y_test.ravel()

#training the algorithm
grid_search.fit(X_train, Y_train) 

#hyperturning
best_model = grid_search.best_estimator_ 

#Predicting test set
Y_pred = best_model.predict(X_test)
    
print("Best hyperparameters:", grid_search.best_params_)

print(data.iloc[5,0])
print("\033[1mActual is:\033[0m", Y_test)
print ("\033[1mPredicted is:\033[0m", Y_pred)

def rmse(y_true, y_pred):
    # calculate mean squared error for each output
    mse = mean_squared_error(y_true, y_pred, multioutput='raw_values')
    # calculate RMSE for each output
    rmse = np.sqrt(mse)
    return rmse

RMSE=rmse(Y_test, Y_pred)
print(RMSE)
# Out:
# Best hyperparameters: {'C': 10, 'epsilon': 0.1}
# PD05
# Actual is: [2.07411 2.07411]
# Predicted is: [2.00848053 1.5102821 ]
# RMSE is: [0.40137833]

# %%
#testing MATERIAL C - coefficient2
X_train = data.iloc[list(range(0,4))+ list(range(6, len(data)))].iloc[:,3:].values
Y_train = data.iloc[list(range(0,4)) +list(range(6, len(data)))].iloc[:,2:3].values
X_test = data.iloc[4:6,3:].values
Y_test = data.iloc[4:6,2:3].values

#scaling the data
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

Y_train=Y_train.ravel()
Y_test=Y_test.ravel()

#training the algorithm
grid_search.fit(X_train, Y_train) 

#hyperturning
best_model = grid_search.best_estimator_ 

#Predicting test set
Y_pred = best_model.predict(X_test)
    
print("Best hyperparameters:", grid_search.best_params_)
print(data.iloc[5,0])
print("\033[1mActual is:\033[0m", Y_test)
print ("\033[1mPredicted is:\033[0m", Y_pred)

def rmse(y_true, y_pred):
    # calculate mean squared error for each output
    mse = mean_squared_error(y_true, y_pred, multioutput='raw_values')
    # calculate RMSE for each output
    rmse = np.sqrt(mse)
    return rmse

RMSE=rmse(Y_test, Y_pred)
print(RMSE)
# Out:
# Best hyperparameters: {'C': 0.1, 'epsilon': 0.1}
# PD05
# Actual is: [1.569432 1.569432]
# Predicted is: [1.67673256 1.47221602]
# RMSE is: [0.10238251]

# %%
#testing MATERIAL D - coefficient1
X_train = data.iloc[list(range(0,6))+ list(range(8, len(data)))].iloc[:,3:].values
Y_train = data.iloc[list(range(0,6)) +list(range(8, len(data)))].iloc[:,1:2].values
X_test = data.iloc[6:8,3:].values
Y_test = data.iloc[6:8,1:2].values

#scaling the data
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

Y_train=Y_train.ravel()
Y_test=Y_test.ravel()

#training the algorithm
grid_search.fit(X_train, Y_train) 

#hyperturning
best_model = grid_search.best_estimator_ 

#Predicting test set
Y_pred = best_model.predict(X_test)
    
print("Best hyperparameters:", grid_search.best_params_)

print(data.iloc[7,0])
print("\033[1mActual is:\033[0m", Y_test)
print ("\033[1mPredicted is:\033[0m", Y_pred)

def rmse(y_true, y_pred):
    # calculate mean squared error for each output
    mse = mean_squared_error(y_true, y_pred, multioutput='raw_values')
    # calculate RMSE for each output
    rmse = np.sqrt(mse)
    return rmse

RMSE=rmse(Y_test, Y_pred)
print(RMSE)
# Out:
# Best hyperparameters: {'C': 1, 'epsilon': 0.1}
# DS30
# Actual is: [1.530849 1.530849]
# Predicted is: [1.95780814 2.13282861]
# RMSE is: [0.52185896]

# %%
#testing MATERIAL D - coefficient2
X_train = data.iloc[list(range(0,6))+ list(range(8, len(data)))].iloc[:,3:].values
Y_train = data.iloc[list(range(0,6)) +list(range(8, len(data)))].iloc[:,2:3].values
X_test = data.iloc[6:8,3:].values
Y_test = data.iloc[6:8,2:3].values

#scaling the data
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

Y_train=Y_train.ravel()
Y_test=Y_test.ravel()

#training the algorithm
grid_search.fit(X_train, Y_train) 

#hyperturning
best_model = grid_search.best_estimator_ 

#Predicting test set
Y_pred = best_model.predict(X_test)
    
print("Best hyperparameters:", grid_search.best_params_)

print(data.iloc[7,0])
print("\033[1mActual is:\033[0m", Y_test)
print ("\033[1mPredicted is:\033[0m", Y_pred)

def rmse(y_true, y_pred):
    # calculate mean squared error for each output
    mse = mean_squared_error(y_true, y_pred, multioutput='raw_values')
    # calculate RMSE for each output
    rmse = np.sqrt(mse)
    return rmse

RMSE=rmse(Y_test, Y_pred)
print(RMSE)
# Out:
# Best hyperparameters: {'C': 10, 'epsilon': 0.1}
# DS30
# Actual is: [1.578501 1.578501]
# Predicted is: [1.44808912 1.48378675]
# RMSE is: [0.1139694]

# %%
#testing MATERIAL E - coefficient1
X_train = data.iloc[list(range(0,8))+ list(range(10, len(data)))].iloc[:,3:].values
Y_train = data.iloc[list(range(0,8)) +list(range(10, len(data)))].iloc[:,1:2].values
X_test = data.iloc[8:10,3:].values
Y_test = data.iloc[8:10,1:2].values

#scaling the data
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

Y_train=Y_train.ravel()
Y_test=Y_test.ravel()

#training the algorithm
grid_search.fit(X_train, Y_train) 

#hyperturning
best_model = grid_search.best_estimator_ 

#Predicting test set
Y_pred = best_model.predict(X_test)
    
print("Best hyperparameters:", grid_search.best_params_)

print(data.iloc[9,0])
print("\033[1mActual is:\033[0m", Y_test)
print ("\033[1mPredicted is:\033[0m", Y_pred)

def rmse(y_true, y_pred):
    # calculate mean squared error for each output
    mse = mean_squared_error(y_true, y_pred, multioutput='raw_values')
    # calculate RMSE for each output
    rmse = np.sqrt(mse)
    return rmse

RMSE=rmse(Y_test, Y_pred)
print(RMSE)
# Out:
# Best hyperparameters: {'C': 1, 'epsilon': 0.1}
# EF50
# Actual is: [2.815642 2.815642]
# Predicted is: [2.30891212 2.68652083]
# RMSE is: [0.36976172]

# %%
#testing MATERIAL E - coefficient2
X_train = data.iloc[list(range(0,8))+ list(range(10, len(data)))].iloc[:,3:].values
Y_train = data.iloc[list(range(0,8)) +list(range(10, len(data)))].iloc[:,2:3].values
X_test = data.iloc[8:10,3:].values
Y_test = data.iloc[8:10,2:3].values

#scaling the data
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

Y_train=Y_train.ravel()
Y_test=Y_test.ravel()

#training the algorithm
grid_search.fit(X_train, Y_train) 

#hyperturning
best_model = grid_search.best_estimator_ 

#Predicting test set
Y_pred = best_model.predict(X_test)
    
print("Best hyperparameters:", grid_search.best_params_)

print(data.iloc[9,0])
print("\033[1mActual is:\033[0m", Y_test)
print ("\033[1mPredicted is:\033[0m", Y_pred)

def rmse(y_true, y_pred):
    # calculate mean squared error for each output
    mse = mean_squared_error(y_true, y_pred, multioutput='raw_values')
    # calculate RMSE for each output
    rmse = np.sqrt(mse)
    return rmse

RMSE=rmse(Y_test, Y_pred)
print(RMSE)
# Out:
# Best hyperparameters: {'C': 0.1, 'epsilon': 0.1}
# EF50
# Actual is: [1.966655 1.966655]
# Predicted is: [1.80249685 1.92754406]
# RMSE is: [0.11932637]

# %%
#testing MATERIAL F - coefficient1
X_train = data.iloc[list(range(0,10))+ list(range(12, len(data)))].iloc[:,3:].values
Y_train = data.iloc[list(range(0,10)) +list(range(12, len(data)))].iloc[:,1:2].values
X_test = data.iloc[10:12,3:].values
Y_test = data.iloc[10:12,1:2].values

#scaling the data
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

Y_train=Y_train.ravel()
Y_test=Y_test.ravel()

#training the algorithm
grid_search.fit(X_train, Y_train) 

#hyperturning
best_model = grid_search.best_estimator_ 

#Predicting test set
Y_pred = best_model.predict(X_test)
    
print("Best hyperparameters:", grid_search.best_params_)

print(data.iloc[11,0])
print("\033[1mActual is:\033[0m", Y_test)
print ("\033[1mPredicted is:\033[0m", Y_pred)

def rmse(y_true, y_pred):
    # calculate mean squared error for each output
    mse = mean_squared_error(y_true, y_pred, multioutput='raw_values')
    # calculate RMSE for each output
    rmse = np.sqrt(mse)
    return rmse

RMSE=rmse(Y_test, Y_pred)
print(RMSE)
# Out:
# Best hyperparameters: {'C': 10, 'epsilon': 0.1}
# F
# Actual is: [0.680168 0.680168]
# Predicted is: [0.30218663 0.6877631 ]
# RMSE is: [0.26732714]

# %%
#testing MATERIAL F - coefficient2
X_train = data.iloc[list(range(0,10))+ list(range(12, len(data)))].iloc[:,3:].values
Y_train = data.iloc[list(range(0,10)) +list(range(12, len(data)))].iloc[:,2:3].values
X_test = data.iloc[10:12,3:].values
Y_test = data.iloc[10:12,2:3].values

#scaling the data
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

Y_train=Y_train.ravel()
Y_test=Y_test.ravel()

#training the algorithm
grid_search.fit(X_train, Y_train) 

#hyperturning
best_model = grid_search.best_estimator_ 

#Predicting test set
Y_pred = best_model.predict(X_test)
    
print("Best hyperparameters:", grid_search.best_params_)

print(data.iloc[11,0])
print("\033[1mActual is:\033[0m", Y_test)
print ("\033[1mPredicted is:\033[0m", Y_pred)

def rmse(y_true, y_pred):
    # calculate mean squared error for each output
    mse = mean_squared_error(y_true, y_pred, multioutput='raw_values')
    # calculate RMSE for each output
    rmse = np.sqrt(mse)
    return rmse

RMSE=rmse(Y_test, Y_pred)
print(RMSE)
# Out:
# Best hyperparameters: {'C': 1, 'epsilon': 0.1}
# F
# Actual is: [1.381599 1.381599]
# Predicted is: [1.5332686  1.60550336]
# RMSE is: [0.1912287]
